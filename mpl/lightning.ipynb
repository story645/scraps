# %% [markdown]
# # Categorical Color
# ## @story645

# %% [markdown]
# ![cat23](cat23.png)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(15,10), facecolor='#F5F5F5')
_ = ax.set_title("Suggested Python Fluency for Scipy 2019 Sprints", fontsize=24)
_ = ax.bar(['Beginner', 'Intermediate', 'Advanced'], 
           [11,4,1], color=['#BDC566', '#F2E38A', '#FDA781'])
ax.tick_params(axis = 'both', which = 'major', labelsize = 18)
fig.savefig("cat23.png", facecolor="#F5F5F5")

# %% [markdown]
# # What's next @matplotlib:
# ## user set category order
# ## categorical colormapping
# ## improved catergorical color cycles & color maps

# %% [markdown]
# ## Help us be colorblind friendly!
# # https://colorcyclesurvey.mpetroff.net/
# ### Matthew Petroff(@petroffm)

# %% [markdown]
# # Want to talk about data types?
# # Beaks BOF Today!
# # 6:00-7:00PM, Room 101
# (Thanks @dillonniederhut for the name 😄)
